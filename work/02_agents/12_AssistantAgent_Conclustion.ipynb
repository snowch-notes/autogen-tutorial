# %% [markdown]
# # Conclusion
#
# You have now been exposed to many details of AssistantAgent.
#
# Familiarise yourself with the flow.

# %% [markdown]
# <img src="data:image/png;base64,..."/>
#
# Source: https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.agents.html#autogen_agentchat.agents.AssistantAgent
